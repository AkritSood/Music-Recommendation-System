# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv(r'C:\Users\KN\Desktop\MusicRecommendationSystem\SpotifyAudioFeaturesNov2018.csv')
dataset = dataset.sample(frac=0.1, random_state = 1)

# %%
X = dataset.iloc[:, [3,4]].values
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 41):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(10,6))
plt.plot(range(1, 41), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
kmeans = KMeans(n_clusters = 15, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)
plt.figure(figsize=(10,6))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 5, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 5, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 5, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 5, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 5, c = 'magenta', label = 'Cluster 5')
plt.scatter(X[y_kmeans == 5, 0], X[y_kmeans == 5, 1], s = 5, c = 'Pink', label = 'Cluster 6')
plt.scatter(X[y_kmeans == 6, 0], X[y_kmeans == 6, 1], s = 5, c = 'black', label = 'Cluster 7')
plt.scatter(X[y_kmeans == 7, 0], X[y_kmeans == 7, 1], s = 5, c = 'yellow', label = 'Cluster 8')
plt.scatter(X[y_kmeans == 8, 0], X[y_kmeans == 8, 1], s = 5, c = 'purple', label = 'Cluster 9')
plt.scatter(X[y_kmeans == 9, 0], X[y_kmeans == 9, 1], s = 5, c = 'DarkBlue', label = 'Cluster 10')
plt.scatter(X[y_kmeans == 10, 0], X[y_kmeans == 10, 1], s = 5, c = 'Maroon', label = 'Cluster 11')
plt.scatter(X[y_kmeans == 11, 0], X[y_kmeans == 11, 1], s = 5, c = 'brown', label = 'Cluster 12')
plt.scatter(X[y_kmeans == 12, 0], X[y_kmeans == 12, 1], s = 5, c = 'orange', label = 'Cluster 13')
plt.scatter(X[y_kmeans == 13, 0], X[y_kmeans == 13, 1], s = 5, c = 'silver', label = 'Cluster 14')
plt.scatter(X[y_kmeans == 14, 0], X[y_kmeans == 14, 1], s = 5, c = 'lime', label = 'Cluster 15')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'Olive', label = 'Centroids',alpha=0.5)
plt.title('Clusters of accoustiness vs danceability')
plt.xlabel('accoustiness')
plt.ylabel('dancebility')
plt.legend(loc='best')
plt.show()
