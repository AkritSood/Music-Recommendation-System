# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv(r'C:\Users\KN\Desktop\MusicRecommendationSystem\SpotifyAudioFeaturesNov2018.csv')
dataset = dataset.sample(frac=0.1, random_state = 1)
musicdata = dataset.pivot_table(index = 'artist_name',columns = 'track_name',values='popularity')
dataset.sort_values('popularity',ascending=False).head(10)
# Out:
#                 artist_name                track_id       track_name  \
# 109540           Marshmello  2dpaYNEQHiRxtZbfNsse99          Happier
# 109550          Post Malone  7dt6x5M1jzdTEt8oCbisTK       Better Now
# 109862              Becky G  2XXMDz7SPZ4mSFN1PXfHUy   Cuando Te Besé
# 109632             Rita Ora  6xtcFXSo8H9BZN637BMVKS  Let You Love Me
# 109600           Nio Garcia  3V8UKqhEK5zBkBb6d6ub8i  Te Boté - Remix
# 109565       French Montana  04MLEeAMuV9IlHEsD8vF6A       No Stylist
# 109808                Ozuna  1h9P5WJwyvK8OB7O2YiXgp            Ibiza
# 110327           Pedro Capó  5iwz1NiezX7WWjnCgY5TH4    Calma - Remix
# 109622  5 Seconds of Summer  55S2PQgSMYAhgoTCcGCDfw       Youngblood
# 109659           Bebe Rexha  04ZTP5KsCypmtCmQg5tH9R       I'm a Mess
#
#         acousticness  danceability  duration_ms  energy  instrumentalness  \
# 109540       0.19100         0.687       214290   0.792          0.000000
# 109550       0.35400         0.680       231267   0.563          0.000000
# 109862       0.30700         0.772       254383   0.732          0.000005
# 109632       0.28800         0.531       190000   0.854          0.000000
# 109600       0.54200         0.903       417920   0.675          0.000013
# 109565       0.02150         0.765       192172   0.704          0.000000
# 109808       0.25400         0.691       200747   0.710          0.000000
# 110327       0.32300         0.826       238200   0.773          0.000000
# 109622       0.01690         0.596       203418   0.854          0.000000
# 109659       0.00281         0.630       195519   0.694          0.000000
#
#         key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# 109540    5    0.1670    -2.749     1       0.0452  100.015               4
# 109550   10    0.1360    -5.843     1       0.0454  145.028               4
# 109862    9    0.1060    -3.713     0       0.2130  100.048               4
# 109632   10    0.0773    -3.149     1       0.1980   94.419               4
# 109600   11    0.0595    -3.445     0       0.2140   96.507               4
# 109565    5    0.2270    -4.589     0       0.1270  147.055               4
# 109808    5    0.1080    -5.144     1       0.3340  192.046               4
# 110327   11    0.1430    -4.218     0       0.0524  126.899               4
# 109622    7    0.1240    -5.114     0       0.4630  120.274               4
# 109659   11    0.0719    -6.257     0       0.0253   97.005               4
#
#         valence  popularity
# 109540    0.671          96
# 109550    0.374          92
# 109862    0.295          90
# 109632    0.456          90
# 109600    0.442          89
# 109565    0.498          89
# 109808    0.726          86
# 110327    0.761          86
# 109622    0.152          85
# 109659    0.216          85
