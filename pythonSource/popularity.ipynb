# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv(r'C:\Users\KN\Desktop\MusicRecommendationSystem\SpotifyAudioFeaturesNov2018.csv')
dataset = dataset.sample(frac=0.1, random_state = 1)
musicdata = dataset.pivot_table(index = 'artist_name',columns = 'track_name',values='popularity')
musicdata
# Out:
# track_name             "Everybody Told Me"  "Hello, I’m James Halliday"  \
# artist_name
# !!!                                    NaN                          NaN
# "Puppy Dog Pals" Cast                  NaN                          NaN
# $avage                                 NaN                          NaN
# $mooth thoma$                          NaN                          NaN
# $tupid Young                           NaN                          NaN
# ...                                    ...                          ...
# 蘇詩丁                                    NaN                          NaN
# 霍尊                                     NaN                          NaN
# 騰格爾                                    NaN                          NaN
# 바로                                     NaN                          NaN
# 유나                                     NaN                          NaN
#
# track_name             "You Get so Alone at Times That It Just Makes Sense"  \
# artist_name
# !!!                                                                  NaN
# "Puppy Dog Pals" Cast                                                NaN
# $avage                                                               NaN
# $mooth thoma$                                                        NaN
# $tupid Young                                                         NaN
# ...                                                                  ...
# 蘇詩丁                                                                  NaN
# 霍尊                                                                   NaN
# 騰格爾                                                                  NaN
# 바로                                                                   NaN
# 유나                                                                   NaN
#
# track_name             #Dprimera  #DuduZar  $$$$  'Til It's Over  (4am) loops  \
# artist_name
# !!!                          NaN       NaN   NaN             NaN          NaN
# "Puppy Dog Pals" Cast        NaN       NaN   NaN             NaN          NaN
# $avage                       NaN       NaN   NaN             NaN          NaN
# $mooth thoma$                NaN       NaN   NaN             NaN          NaN
# $tupid Young                 NaN       NaN   NaN             NaN          NaN
# ...                          ...       ...   ...             ...          ...
# 蘇詩丁                          NaN       NaN   NaN             NaN          NaN
# 霍尊                           NaN       NaN   NaN             NaN          NaN
# 騰格爾                          NaN       NaN   NaN             NaN          NaN
# 바로                           NaN       NaN   NaN             NaN          NaN
# 유나                           NaN       NaN   NaN             NaN          NaN
#
# track_name             (Everything I Do) I Do It For You  \
# artist_name
# !!!                                                  NaN
# "Puppy Dog Pals" Cast                                NaN
# $avage                                               NaN
# $mooth thoma$                                        NaN
# $tupid Young                                         NaN
# ...                                                  ...
# 蘇詩丁                                                  NaN
# 霍尊                                                   NaN
# 騰格爾                                                  NaN
# 바로                                                   NaN
# 유나                                                   NaN
#
# track_name             **Bonus Track** Put Your Hands Up  ...  \
# artist_name                                               ...
# !!!                                                  NaN  ...
# "Puppy Dog Pals" Cast                                NaN  ...
# $avage                                               NaN  ...
# $mooth thoma$                                        NaN  ...
# $tupid Young                                         NaN  ...
# ...                                                  ...  ...
# 蘇詩丁                                                  NaN  ...
# 霍尊                                                   NaN  ...
# 騰格爾                                                  NaN  ...
# 바로                                                   NaN  ...
# 유나                                                   NaN  ...
#
# track_name             麗しき世界 Re:boot (Instrumental)  낮 꿈 Day Dream  \
# artist_name
# !!!                                             NaN            NaN
# "Puppy Dog Pals" Cast                           NaN            NaN
# $avage                                          NaN            NaN
# $mooth thoma$                                   NaN            NaN
# $tupid Young                                    NaN            NaN
# ...                                             ...            ...
# 蘇詩丁                                             NaN            NaN
# 霍尊                                              NaN            NaN
# 騰格爾                                             NaN            NaN
# 바로                                              NaN            NaN
# 유나                                              NaN            NaN
#
# track_name             달려! Relay - Inst.  복을 발로 차버렸어 I kicked my luck off  \
# artist_name
# !!!                                  NaN                              NaN
# "Puppy Dog Pals" Cast                NaN                              NaN
# $avage                               NaN                              NaN
# $mooth thoma$                        NaN                              NaN
# $tupid Young                         NaN                              NaN
# ...                                  ...                              ...
# 蘇詩丁                                  NaN                              NaN
# 霍尊                                   NaN                              NaN
# 騰格爾                                  NaN                              NaN
# 바로                                   NaN                              NaN
# 유나                                   NaN                              NaN
#
# track_name             사랑했다고 That You Loved Me  \
# artist_name
# !!!                                        NaN
# "Puppy Dog Pals" Cast                      NaN
# $avage                                     NaN
# $mooth thoma$                              NaN
# $tupid Young                               NaN
# ...                                        ...
# 蘇詩丁                                        NaN
# 霍尊                                         NaN
# 騰格爾                                        NaN
# 바로                                         NaN
# 유나                                         NaN
#
# track_name             새해 복 New Year's Luck - K-Wave Ver.  시간 차 Too Late  \
# artist_name
# !!!                                                   NaN            NaN
# "Puppy Dog Pals" Cast                                 NaN            NaN
# $avage                                                NaN            NaN
# $mooth thoma$                                         NaN            NaN
# $tupid Young                                          NaN            NaN
# ...                                                   ...            ...
# 蘇詩丁                                                   NaN            NaN
# 霍尊                                                    NaN            NaN
# 騰格爾                                                   NaN            NaN
# 바로                                                    NaN            NaN
# 유나                                                    NaN            NaN
#
# track_name             와플 #Hashtag  운명 The Chance of Love  원하니까 Still
# artist_name
# !!!                            NaN                    NaN         NaN
# "Puppy Dog Pals" Cast          NaN                    NaN         NaN
# $avage                         NaN                    NaN         NaN
# $mooth thoma$                  NaN                    NaN         NaN
# $tupid Young                   NaN                    NaN         NaN
# ...                            ...                    ...         ...
# 蘇詩丁                            NaN                    NaN         NaN
# 霍尊                             NaN                    NaN         NaN
# 騰格爾                            NaN                    NaN         NaN
# 바로                             NaN                    NaN         NaN
# 유나                             NaN                    NaN         NaN
#
# [7409 rows x 11086 columns]

# %%
musicdata = dataset.pivot_table(index = 'artist_name',columns = 'track_name',values='popularity')
