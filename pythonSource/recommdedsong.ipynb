# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
# %matplotlib inline
dataset = pd.read_csv(r'C:\Users\KN\Desktop\MusicRecommendationSystem\SpotifyAudioFeaturesNov2018.csv')
dataset = dataset.sample(frac=0.1, random_state = 1)
musicdata = dataset.pivot_table(index = 'artist_name',columns = 'track_name',values='popularity')
dataset.sort_values('popularity',ascending=False).head(10)
dataset.sort_values('popularity',ascending=False).iloc[:,-1]
music_popularity1=dataset.loc[dataset['track_name'] == random.choice(list(dataset['track_name']))]
music_popularity2=dataset.loc[dataset['track_name'] == random.choice(list(dataset['track_name']))]
p=music_popularity1['popularity']
pp=int(p)
sim_Sucker=dataset.loc[dataset['popularity'] ==pp]
print(sim_Sucker)
# Out:
#                   artist_name                track_id  \
# 73157       Waka Flocka Flame  1zvviV9pxWxDVxXTo2NkDK
# 66873                  Basick  0qlAeGrWIYasGyrhXo6IhY
# 41184                Exolight  6b6QCmvnlQ3PCeH2faVVaz
# 83193  The One Shot Finalists  63nUybeX0L16M0qSxBxwgx
# 81219     Visions of Atlantis  0ignT8MUwnUYKxHJALgeP0
# ...                       ...                     ...
# 62122                 Shun Yu  6yo8E6qgf3CGtlnEcPHj9W
# 40144       Hermanos Vega Jr.  0BH6UcVx9fJrvYj3axw8DY
# 39024                Don Jose  4dwPgsNtn4F9Q27FKtEh3S
# 85133                Beatking  1F4be5yAel6SiSuE2dsvkr
# 93903   Johann Sebastian Bach  6O8DkYxn0MYXm2IugQOa55
#
#                                               track_name  acousticness  \
# 73157  One Squad (feat. Blair Maxberry & Cartier Kitten)      0.073500
# 66873                            Microphone Checker (MC)      0.087600
# 41184                  Footprints On The Moon (ASOT 857)      0.000183
# 83193                                     TV Theme Stuff      0.013700
# 81219                                       Ritual Night      0.000044
# ...                                                  ...           ...
# 62122  Sonata in A-flat Major, Op. 11 (Ludwig van Bee...      0.985000
# 40144                                  La Vida de Rancho      0.670000
# 39024                                               Dime      0.269000
# 85133                                             Bad AF      0.005560
# 93903  Violin Sonata in G Major, BWV 1019: I. Allegro...      0.845000
#
#        danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 73157         0.786       248633  0.4730          0.000000    8    0.1070
# 66873         0.537       216638  0.7440          0.000000    6    0.2540
# 41184         0.389       157160  0.7310          0.026200    5    0.5760
# 83193         0.524        58227  0.6520          0.835000    9    0.0782
# 81219         0.260       238680  0.7130          0.004110    2    0.0900
# ...             ...          ...     ...               ...  ...       ...
# 62122         0.423      1189114  0.0264          0.896000    8    0.0690
# 40144         0.685       247629  0.5440          0.000000    8    0.1010
# 39024         0.807       144065  0.7120          0.000000   10    0.0814
# 85133         0.883       202896  0.5610          0.000000   10    0.0803
# 93903         0.509       227072  0.3760          0.000013    6    0.1480
#
#        loudness  mode  speechiness    tempo  time_signature  valence  \
# 73157    -5.305     1       0.0750  140.013               4   0.0674
# 66873    -3.001     0       0.1770   85.232               4   0.2730
# 41184   -12.228     0       0.0713  135.991               4   0.1460
# 83193    -8.178     1       0.0298  135.886               4   0.1760
# 81219    -9.139     0       0.0450  103.420               3   0.3200
# ...         ...   ...          ...      ...             ...      ...
# 62122   -28.057     1       0.0469  133.893               4   0.0495
# 40144    -2.961     1       0.0323  148.619               3   0.9560
# 39024    -4.652     0       0.0863  119.998               4   0.7920
# 85133    -6.348     0       0.3440  154.071               4   0.2380
# 93903   -18.588     1       0.0355   98.972               4   0.9600
#
#        popularity
# 73157          12
# 66873          12
# 41184          12
# 83193          12
# 81219          12
# ...           ...
# 62122          12
# 40144          12
# 39024          12
# 85133          12
# 93903          12
#
# [234 rows x 17 columns]
